# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('finance_data.csv')

# %%
df
# Out:
#          Date  Close_AAPL   High_AAPL    Low_AAPL   Open_AAPL  Volume_AAPL  \
# 0  2025-03-31  222.130005  225.619995  216.229996  217.009995     65299300
# 1  2025-04-01  223.190002  223.679993  218.899994  219.809998     36412700
# 2  2025-04-02  223.889999  225.190002  221.020004  221.320007     35905900
# 3  2025-04-03  203.190002  207.490005  201.250000  205.539993    103419000
# 4  2025-04-04  188.380005  199.880005  187.339996  193.889999    125910900
# 5  2025-04-07  181.460007  194.149994  174.619995  177.199997    160466300
# 6  2025-04-08  172.419998  190.339996  169.210007  186.699997    120859500
# 7  2025-04-09  198.850006  200.610001  171.889999  171.949997    184395900
# 8  2025-04-10  190.419998  194.779999  183.000000  189.070007    121880000
# 9  2025-04-11  198.149994  199.539993  186.059998  186.100006     87300000
#
#            Firm_AAPL ToGrade_AAPL FromGrade_AAPL Action_AAPL  ...  Action_IBM  \
# ...

# %%
target_cols = [col for col in df.columns if 'Close' in col]

# %%
target_cols
# Out:
# ['Close_AAPL',
#  'Close_MSFT',
#  'Close_GOOGL',
#  'Close_AMZN',
#  'Close_META',
#  'Close_NVDA',
#  'Close_TSLA',
#  'Close_ADBE',
#  'Close_CRM',
#  'Close_ORCL',
#  'Close_INTC',
#  'Close_CSCO',
#  'Close_AMD',
#  'Close_IBM',
#  'Close_QCOM']
