# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime as dt

# %%
df = pd.read_csv('finance_data.csv')

# %%
df
# Out:
#           Date  Close_AAPL   High_AAPL    Low_AAPL   Open_AAPL  Volume_AAPL  \
# 0   2025-03-17  214.000000  215.220001  209.970001  213.309998     48073400
# 1   2025-03-18  212.690002  215.149994  211.490005  214.160004     42432400
# 2   2025-03-19  215.240005  218.759995  213.750000  214.220001     54385400
# 3   2025-03-20  214.100006  217.490005  212.220001  213.990005     48862900
# 4   2025-03-21  218.270004  218.839996  211.279999  211.559998     94127800
# 5   2025-03-24  220.729996  221.479996  218.580002  221.000000     44299500
# 6   2025-03-25  223.750000  224.100006  220.080002  220.770004     34493600
# 7   2025-03-26  221.529999  225.020004  220.470001  223.509995     34466100
# 8   2025-03-27  223.850006  224.990005  220.559998  221.389999     37094800
# 9   2025-03-28  217.899994  223.809998  217.679993  221.669998     39818600
# 10  2025-03-31  222.130005  225.619995  216.229996  217.009995     65299300
# ...

# %%
target_cols = [col for col in df.columns if 'Close' in col]

# %%
target_cols
# Out:
# ['Close_AAPL',
#  'Close_MSFT',
#  'Close_NVDA',
#  'Close_AVGO',
#  'Close_ORCL',
#  'Close_CRM',
#  'Close_CSCO',
#  'Close_IBM',
#  'Close_PLTR',
#  'Close_ACN']

# %%
df.plot(x='Date', y= 'Close_AAPL')
# Out:
# <Axes: xlabel='Date'>

# %%
yf.download(tickers=['AAPL','MSFT'], period='1d')
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price            Close               High                    Low              \
# Ticker            AAPL        MSFT   AAPL       MSFT        AAPL        MSFT
# Date
# 2025-04-28  210.139999  391.160004  211.5  392.73999  207.460007  386.640015
#
# Price        Open                Volume
# Ticker       AAPL        MSFT      AAPL      MSFT
# Date
# 2025-04-28  210.0  391.959991  38652400  16536000
